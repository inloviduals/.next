# %% [markdown]
# <a href="https://colab.research.google.com/github/inloviduals/.next/blob/master/test-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
# !ls -l
# Out:
# total 4
# drwxr-xr-x 1 root root 4096 Mar  5 14:37 sample_data

# %%
import numpy as np
a = np.array([1,2,3,4])
print(a)
c = np.arr
# Out:
# [1 2 3 4]

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Fills and Alpha Example")
plt.show()
